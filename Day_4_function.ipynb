# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Day_4_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def chaohoi():
  print("Hello world!")

chaohoi()

def chaohoi1(a):
   print(f"Hello {a}")
   chaohoi()

chaohoi1("HUY")

danhsach=["Huy", "Phương", "Phụng", "Tuấn"]

def xulylist(a):
  return(len(a))

print(xulylist(danhsach ))
# Out:
# Hello world!
# Hello HUY
# Hello world!
# 4
