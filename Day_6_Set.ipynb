# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Day_6_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Friends = {'Phương','Tuấn','Phụng','Hùng'}
Your_friends ={'Ngọc Trinh','Khánh Linh','Hùng'}
print(Friends.union(Your_friends))
print(Friends.intersection(Your_friends))
print(Friends.difference(Your_friends))
# Out:
# {'Ngọc Trinh', 'Phương', 'Khánh Linh', 'Phụng', 'Tuấn', 'Hùng'}
# {'Hùng'}
# {'Phụng', 'Tuấn', 'Phương'}
