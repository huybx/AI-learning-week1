# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Day_2_Dictionary_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
listA=[1,2,3,4,5,6]
tupleA=(10,20,30,40,50,60)
DictB={
        "Linh":90,
        "Trinh":30,
        "Diễm Ny":80   ,

}
print(listA, tupleA, DictB)
print(f"số lớn nhất của List A {max(listA)}")
print(f"số nhỏ nhất của tupleA là {min(tupleA)}")
listA.append(100)
listA.sort(reverse=True)
print(listA)
print(listA.pop(1))
#tupleA.pop(1)
print(DictB.get("Linh"))
DictB.update({"Ngân 98": 100})
for key,value in DictB.items():
  print(f"size vú của {key} là {value}")
# Out:
# [1, 2, 3, 4, 5, 6] (10, 20, 30, 40, 50, 60) {'Linh': 90, 'Trinh': 30, 'Diễm Ny': 80}
# số lớn nhất của List A 6
# số nhỏ nhất của tupleA là 10
# [100, 6, 5, 4, 3, 2, 1]
# 6
# 90
# size vú của Linh là 90
# size vú của Trinh là 30
# size vú của Diễm Ny là 80
# size vú của Ngân 98 là 100
