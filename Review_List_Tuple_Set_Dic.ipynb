# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Review_List_Tuple_Set_Dic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
#list a = [1,2,3]
# khởi tạo list rỗng
mylist = []
#tuble b = (1,2,3)
# khởi tạo tuble rỗng
mytuble = ()
#set c ={1,2,3}
# khởi tạo set rỗng
myset = set ()
#myset = {} #đây là khởi tạo dict rỗng, không phải khởi tạo set
mydict = {}

print(type(mylist), type(mytuble), type(myset), type(mydict))
"""# list có thể thay đổi, thêm bớt giá trị, tuble thì không.
mylist1 = [1,2,3]
for i in mylist1: #truy cập theo giá trị
   print (i)
   mylist.append(i)

for i in range(0,len(mylist1)): #truy cập theo index, từ không tới len(mylist1)-1
   mylist.append(mylist1[i])

#xoá một phần từ từ list theo giá trị
for i in mylist:
   if i == 3:
    mylist.remove(i)
    break
#xoá một phần tử từ list theo index
for i in range(0, len(mylist)):
   if mylist[i]==2:
    a= mylist.remove(mylist[i]) #a được gán là none, phương thức remove không trả về giá trị bị xoá
    break

#lấy một phần từ ra khỏi list và xoá phần tử đó dùng phương thức pop
a= mylist.pop(1) #lấy phần tử thứ 2
b=mylist.pop(-1) #lấy phần tử cuối list index < 0 là xử lý ngược từ cuối list lên
c=mylist.pop()#lấy phần tử cuối list
# mylist.clear() #xoá hết nội dung của list --> còn list rỗng
a= mylist.count(2) #đếm số lần xuất hiện của một giá trị trong list
mylist.extend(mylist1) #gắn list mylist1 vào cuối mylist
d=mylist.copy() #sao chép 1 list
mylist.reverse()
print(d, mylist)
#del(mylist) #xoá mylist
#tạo ngẫu nhiên một danh sách
#tạo ngẫu nhiên một phần tử và thêm vào danh sách
mylist.clear()
n=5
for i in range(0,n):
  mylist.append(random.randrange(0,100,2)) #tạo ngẫu nhiên một  từ 2   đến 100  bước nhảy là 1

for i in range(0,n):
  mylist.append(random.randint(1,100)) #tạo ngẫu nhiên một số từ 1 đế 99, randint không có bước nhảy

mylist.extend(random.sample(range(2,100),5)) #thêm vào 5 phần tử ngẫu nhiên và duy nhất

mylist.append(random.choice(mylist1)) #chọn ngẫu nhiên một phần từ từ  danh sách mylist1
#random.choice(sequence). sequence là list, tuple, range - không dùng set hay dict
#random.sample(population,k). population là list, tuple, range, set - không dùng dict

try:
  print(mylist)
except NameError as err:
  print(f"lỗi {err}")
""" #list có thể thay đổi, thêm bớt giá trị, tuble thì không.
"""
mytuble1 = (1,2,30,3)
mytuble = ()
mylist=[1,2,1,1]


a =mytuble1.count(3)
b=mytuble1.index(2) #vị trí của 2 trong tuble
c=mylist.index(1) #vị trí của 3 trong list
mylist.insert(3,20) #tuble không có phương thức insert, pop hay remove, append,extend, sort,clear
mylist.sort(reverse=True)
mytuble = mytuble1

#các cách bổ sung phần tử mới cho 1 tuple tuble + tuble
mytuble =mytuble1 +(100,)

#tuble không sắp thứ tự được nhưng có thể chuyển sang list sắp thứ tự rồi chuyển về tuble
mylist=list(mytuble)
#các cách bổ sung giá trị vào tuble: chuyển từ tuble sang list, thêm giá trị và chuyển list đó về tuble - xoá cũng vậy

mylist.sort()
mytuble=tuple(mylist)
#các cách bổ sung một tuble vào 1 tuble dùng toán tử unpack
mytuble = (*mytuble, *mytuble, 1,2, 100)



try:
  print(mytuble, mylist , a, b, c)
except NameError as err:
  print(f"lỗi {err}")"""
"""
#set không có thứ tự, mỗi phần tử là duy nhất, có các phương thức, giao hội trừ.
myset1 ={1,4,2,4,5,5}
myset={4,2,10}
myset1.add(6)
myset1.add(3)
a1=myset1.pop()
b=myset1.remove(3)
c=myset1.discard(200)

#myset1.clear()
a=myset.issubset(myset1)
mylist=list(myset)
mylist.extend(random.sample(range(2,2000),15))
myset1=set(mylist)
f=myset.intersection_update(myset1)
print(myset1,myset,mylist,a,a1,b,c,f)
"""# dict {<key>:<value>}
mydict={"Name":"HUY","Age":42,"Job":"Lecturer"}
Students={1:{"Name":"HUY","Age":42,"Job":"Lecturer"},2:{"Name":"Trinh","Age":30,"Job":"Model"},3:{"Name":"Khánh Linh","Age":25,"Job":"Makeuper"}}
mylist=list(mydict)
myset=set(mydict)
mytuble=tuple(mydict)
mystr=str(mydict)
print(f"{mydict} convert to list: {mylist}") #chỉ còn lại key, không có value
print(f"{mydict} convert to set: {myset}") #chỉ còn lại key, không có value, thứ tự ngẫu nhiên
print(f"{mydict} convert to tuple: {mytuble}") #chỉ còn lại key, không có value
print(f"{mydict} convert to string: {mystr}") #giữ lại được cả key và value

print("#==============================#")
#biết key tìm được value
for i in mydict:  #i là key
  print(f"giá trị của {i} là {mydict[i]}") #mydict[i] là value tương ứng
#biết value tìm được key
for i in ["HUY","Trinh","Khánh Linh"]:
  for j in mydict:
    if mydict[j]==i:
      print(f"giá trị của {j} là {i}")
      break
# Out:
# <class 'list'> <class 'tuple'> <class 'set'> <class 'dict'>
# {'Name': 'HUY', 'Age': 42, 'Job': 'Lecturer'} convert to list: ['Name', 'Age', 'Job']
# {'Name': 'HUY', 'Age': 42, 'Job': 'Lecturer'} convert to set: {'Job', 'Name', 'Age'}
# {'Name': 'HUY', 'Age': 42, 'Job': 'Lecturer'} convert to tuple: ('Name', 'Age', 'Job')
# {'Name': 'HUY', 'Age': 42, 'Job': 'Lecturer'} convert to string: {'Name': 'HUY', 'Age': 42, 'Job': 'Lecturer'}
# #==============================#
# giá trị của Name là HUY
# giá trị của Age là 42
# giá trị của Job là Lecturer
# giá trị của Name là HUY
