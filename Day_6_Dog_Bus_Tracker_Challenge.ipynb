# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Day_6_Dog_Bus_Tracker_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🐾 Dog Bus Tracker — Challenge Steps
from typing import Final
from datetime import datetime, timezone, timedelta
MAX_SEATS: Final = 10 #sức chứa tối đa
current_seat=0 #số khách hiện tại
Dog_Bus = {} #danh sách khách - dùng dictionary


def pickup(): #thêm một hành khách và cho biết số khách hiện tại.
  global current_seat
  name= input("tên thú cưng là gì: ")
  breed = input ("thú cưng thuộc giống nào: ")
  pickup_time =  datetime.now(timezone.utc ).strftime("%H:%M:%S")
  dropoff_time = input("thú cứng được đón lúc mấy giờ: ")
  Dog_Bus.update({current_seat+1:{"name":name,"breed":breed,"pickup_time":pickup_time,"dropoff_time":dropoff_time}})
  current_seat = current_seat+1

def start():
  print(Dog_Bus)


def dropoff(name:str): #thả khách và cho biết số khách còn lại
  global current_seat

  current_seat = current_seat-1




# 1. Start with a bus dictionary holding current passengers.
#    - Each seat number (1, 2, 3, ...) is a key
#    - Each value is another dictionary with each pet's:
#        • name
#        • breed
#        • pickup time
#        • dropoff time
#
# 2. Print a starting roster showing each pet’s seat, name, and pickup time.
#
# 3. Add one new pet if there’s room on the bus.
#    - Use MAX_SEATS to limit capacity.
#    - Dynamically assign the next seat number.
#    - Print the updated roster showing all pets after pickup.
#
# 4. Ask which pet leaves early.
#    - Remove that pet from the bus.
#    - Print a message saying they’ve headed home.
#
# 5. Print a final roster listing the remaining pets and their dropoff times.
# Out:
# tên thú cưng là gì: Husky
# thú cưng thuộc giống nào: Bắc Âu
# {1: {'name': 'Husky', 'breed': 'Bắc Âu', 'pickup_time': '08:36:20', 'dropoff_time': 0}}
