# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Day_6_Dog_Bus_Tracker_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🐾 Dog Bus Tracker — Challenge Steps
from typing import Final
from datetime import datetime, timezone, timedelta
MAX_SEATS: Final = 10 #sức chứa tối đa
current_seat=0 #số khách hiện tại
Dog_Bus = {} #danh sách khách - dùng dictionary

def initial_Dog_Bus():
  i=1
  while i<=MAX_SEATS:
    Dog_Bus.update({i:{}})
    i=i+1

def pickup(): #thêm một hành khách và cho biết số khách hiện tại.
  global current_seat
  name= input("tên thú cưng là gì: ")
  breed = input ("thú cưng thuộc giống nào: ")
  pickup_time =  datetime.now(timezone.utc ).strftime("%H:%M:%S")
  dropoff_time = input("thú cưng được gửi mấy tiếng: ")
  for i in range(1,MAX_SEATS + 1):
    if Dog_Bus[i]== {}:
      Dog_Bus.update({i:{"name":name,"breed":breed,"pickup_time":pickup_time,"dropoff_time":f"trả sau {dropoff_time} giờ"}})
      current_seat = current_seat+1
      break


def start():
  print(Dog_Bus)


def dropoff_name(name:str): #thả khách theo tên và cho biết số khách còn lại
  global current_seat
  count=0
  for i in range(1,MAX_SEATS + 1):
    info=Dog_Bus[i]
    if info and info["name"] == name:
      print(f"{info['name']} đã xuống xe")
      Dog_Bus.update({i:{}})
      current_seat = current_seat-1
      count=count+1
      print(f"số chỗ trống hiện tại là {MAX_SEATS-current_seat}")
  if count==0:
      print(f"khách tên {name} không có trên xe")

def dropoff_seat(seat:int): #thả khách theo số ghế và cho biết số khách còn lại
  global current_seat
  info=Dog_Bus[seat]
  if info != {}:
    print(f"{info['name']} đã xuống xe")
    Dog_Bus.update({seat:{}})
    current_seat = current_seat-1
    print(f"số chỗ trống hiện tại là {MAX_SEATS-current_seat}")
  else:
    print(f"ghế {seat} này không có khách")
#main
initial_Dog_Bus()
num=int(input("số khách sắp lên xe là bao nhiêu: "))
if num <= (MAX_SEATS-current_seat) :
  while num>0:
   print(f"đã có {current_seat} khách trên xe")
   pickup()
   num=num-1
else:
  print("xe quá tải, không nhận khách")

dropoff_seat(3)  #trả khách ghế 3
dropoff_seat(1)  # trả khách ghế 1
pickup()         #thêm 1 khách
print(Dog_Bus)   #in danh sách khách
dropoff_name("Ngân")  #trả khách theo tên
dropoff_name("Linh")  #trả khách theo tên
pickup()              #thêm 1 khách
print(Dog_Bus)          #in danh sách khách
# Out:
# số khách sắp lên xe là bao nhiêu: 5
# đã có 0 khách trên xe
# tên thú cưng là gì: Ngân
# thú cưng thuộc giống nào: VN
# thú cưng được gửi mấy tiếng: 1
# đã có 1 khách trên xe
# tên thú cưng là gì: Linh
# thú cưng thuộc giống nào: Husky
# thú cưng được gửi mấy tiếng: 1
# đã có 2 khách trên xe
# tên thú cưng là gì: Trinh
# thú cưng thuộc giống nào: USA
# thú cưng được gửi mấy tiếng: 3
# đã có 3 khách trên xe
# tên thú cưng là gì: AB
# thú cưng thuộc giống nào: dingo
# thú cưng được gửi mấy tiếng: 1
# đã có 4 khách trên xe
# tên thú cưng là gì: CD
# thú cưng thuộc giống nào: chăn cừu
# thú cưng được gửi mấy tiếng: 2
# Trinh đã xuống xe
# số chỗ trống hiện tại là 6
# Ngân đã xuống xe
# số chỗ trống hiện tại là 7
# tên thú cưng là gì: HH
# thú cưng thuộc giống nào: Sói
# thú cưng được gửi mấy tiếng: 12
# {1: {'name': 'HH', 'breed': 'Sói', 'pickup_time': '12:18:53', 'dropoff_time': 'trả sau 12 giờ'}, 2: {'name': 'Linh', 'breed': 'Husky', 'pickup_time': '12:17:59', 'dropoff_time': 'trả sau 1 giờ'}, 3: {}, 4: {'name': 'AB', 'breed': 'dingo', 'pickup_time': '12:18:19', 'dropoff_time': 'trả sau 1 giờ'}, 5: {'name': 'CD', 'breed': 'chăn cừu', 'pickup_time': '12:18:24', 'dropoff_time': 'trả sau 2 giờ'}, 6: {}, 7: {}, 8: {}, 9: {}, 10: {}}
# khách tên Ngân không có trên xe
# Linh đã xuống xe
# số chỗ trống hiện tại là 7
# tên thú cưng là gì: HA
# thú cưng thuộc giống nào: PQ
# thú cưng được gửi mấy tiếng: 12
# {1: {'name': 'HH', 'breed': 'Sói', 'pickup_time': '12:18:53', 'dropoff_time': 'trả sau 12 giờ'}, 2: {'name': 'HA', 'breed': 'PQ', 'pickup_time': '12:19:10', 'dropoff_time': 'trả sau 12 giờ'}, 3: {}, 4: {'name': 'AB', 'breed': 'dingo', 'pickup_time': '12:18:19', 'dropoff_time': 'trả sau 1 giờ'}, 5: {'name': 'CD', 'breed': 'chăn cừu', 'pickup_time': '12:18:24', 'dropoff_time': 'trả sau 2 giờ'}, 6: {}, 7: {}, 8: {}, 9: {}, 10: {}}
