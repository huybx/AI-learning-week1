# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Day_6_Dog_Bus_Tracker_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🐾 Dog Bus Tracker — Challenge Steps
from typing import Final
from datetime import datetime, timezone, timedelta
MAX_SEATS: Final = 10 #sức chứa tối đa
current_seat=0 #số khách hiện tại
Dog_Bus = {} #danh sách khách - dùng dictionary

def initial_Dog_Bus():
  i=1
  while i<=MAX_SEATS:
    Dog_Bus.update({i:{}})
    i=i+1

def pickup(): #thêm một hành khách và cho biết số khách hiện tại.
  global current_seat
  name= input("tên thú cưng là gì: ")
  breed = input ("thú cưng thuộc giống nào: ")
  pickup_time =  datetime.now(timezone.utc ).strftime("%H:%M:%S")
  dropoff_time = input("thú cưng được gửi mấy tiếng: ")
  for i in range(1,MAX_SEATS + 1):
    if Dog_Bus[i]== {}:
      Dog_Bus.update({i:{"name":name,"breed":breed,"pickup_time":pickup_time,"dropoff_time":f"sau {dropoff_time} giờ"}})
      current_seat = current_seat+1
      break


def start():
  print(Dog_Bus)


def dropoff_name(name:str): #thả khách theo tên và cho biết số khách còn lại
  global current_seat
  count=0
  for i in range(1,MAX_SEATS + 1):
    info=Dog_Bus[i]
    if info and info["name"] == name:
      print(f"{info['name']} đã xuống xe")
      Dog_Bus.update({i:{}})
      current_seat = current_seat-1
      count=count+1
      print(f"số chỗ trống hiện tại là {MAX_SEATS-current_seat}")
  if count==0:
      print("khách này không có trên xe")

def dropoff_seat(seat:int): #thả khách theo số ghế và cho biết số khách còn lại
  global current_seat
  info=Dog_Bus[seat]
  if info != {}:
    print(f"{info['name']} đã xuống xe")
    Dog_Bus.update({seat:{}})
    current_seat = current_seat-1
    print(f"số chỗ trống hiện tại là {MAX_SEATS-current_seat}")
  else:
    print("ghế này không có khách")

initial_Dog_Bus()
num=int(input("số khách sắp lên xe là bao nhiêu: "))
if num <= (MAX_SEATS-current_seat) :
  while num>0:
   print(f"đã có {current_seat} khách trên xe")
   pickup()
   num=num-1
else:
  print("xe quá tải, không nhận khách")
dropoff_seat(3)
dropoff_seat(1)
pickup()
print(Dog_Bus)
dropoff_name("Ngân")
dropoff_name("Linh")
pickup()
print(Dog_Bus)
# Out:
# số khách sắp lên xe là bao nhiêu: 4
# đã có 0 khách trên xe
# tên thú cưng là gì: Khánh Linh
# thú cưng thuộc giống nào: Chó kiểng
# thú cưng được gửi mấy tiếng: 4
# đã có 1 khách trên xe
# tên thú cưng là gì: Ngọc Ngân
# thú cưng thuộc giống nào: Chó Mỹ
# thú cưng được gửi mấy tiếng: 4
# đã có 2 khách trên xe
# tên thú cưng là gì: Ngọc Trinh
# thú cưng thuộc giống nào: Mẫu
# thú cưng được gửi mấy tiếng: 2
# đã có 3 khách trên xe
# tên thú cưng là gì: Thanh Vân
# thú cưng thuộc giống nào: chó bơm
# thú cưng được gửi mấy tiếng: 1
# Ngọc Trinh đã xuống xe
# số chỗ trống hiện tại là 7
# Khánh Linh đã xuống xe
# số chỗ trống hiện tại là 8
# tên thú cưng là gì: Diễm Ny
# thú cưng thuộc giống nào: PT
# thú cưng được gửi mấy tiếng: 2
# {1: {'name': 'Diễm Ny', 'breed': 'PT', 'pickup_time': '11:58:38', 'dropoff_time': 'sau 2 giờ'}, 2: {'name': 'Ngọc Ngân', 'breed': 'Chó Mỹ', 'pickup_time': '11:57:42', 'dropoff_time': 'sau 4 giờ'}, 3: {}, 4: {'name': 'Thanh Vân', 'breed': 'chó bơm', 'pickup_time': '11:58:23', 'dropoff_time': 'sau 1 giờ'}, 5: {}, 6: {}, 7: {}, 8: {}, 9: {}, 10: {}}
# khách này không có trên xe
# khách này không có trên xe
# tên thú cưng là gì: Hoàng
# thú cưng thuộc giống nào: A
# thú cưng được gửi mấy tiếng: 11
# {1: {'name': 'Diễm Ny', 'breed': 'PT', 'pickup_time': '11:58:38', 'dropoff_time': 'sau 2 giờ'}, 2: {'name': 'Ngọc Ngân', 'breed': 'Chó Mỹ', 'pickup_time': '11:57:42', 'dropoff_time': 'sau 4 giờ'}, 3: {'name': 'Hoàng', 'breed': 'A', 'pickup_time': '11:59:10', 'dropoff_time': 'sau 11 giờ'}, 4: {'name': 'Thanh Vân', 'breed': 'chó bơm', 'pickup_time': '11:58:23', 'dropoff_time': 'sau 1 giờ'}, 5: {}, 6: {}, 7: {}, 8: {}, 9: {}, 10: {}}
