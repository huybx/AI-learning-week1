# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Day_4_exercise_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_odd_even(a:int):
  if a%2==0:
    print(f"{a} là số chẵn")
  else:
    print(f"{a} là số lẽ")
  return(a%2)

def tinh_tong(n: int):
  list=[0]
  for i in range(0,n):
    list.append(i+1)
  return(sum(list))

print (f"{tinh_tong(5)}")

def tim_max(l : list):
  return(max(l))

l=[1,2,3,10,100,1]

tim_max(l)

def in_dic(d: dict):
  for key,value in d.items():
    print(f"{key, value}")

d={"Name:":"Huy",
    "diemso:" : 10,
   }

in_dic(d)
# Out:
# 15
# ('Name:', 'Huy')
# ('diemso:', 10)
