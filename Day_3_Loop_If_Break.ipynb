# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Day_3_Loop_If_Break.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("Nhập vào một số nguyên: "))
if num % 3 ==0 and num % 2 ==0:
  print(f"{num} là số chia hết cho 6")
elif num % 3 ==0:
  print(f"{num} là số chia hết cho 3")
elif num % 2 ==0:
  print(f"{num} là số chia hết cho 2")
else:
  print(f"{num} là số bình thường")

for j in range (1,11):
  print(f"đây là bản cửu chương {j}:")
  for i in range (1,11):
    print(f"{j} x {i} = {j*i}")

count=0
while (count <3):
  ans=str(input("Nhập mật khẩu đăng nhập vào hệ thống:"))
  if ans != "AI2026":
     count=count+1
     print(f"Bạn đã đăng nhập sai {count} lần")
  else:
    print("Đăng nhập thành công")
    break
# Out:
# Nhập vào một số nguyên: 11
# 11 là số bình thường
# đây là bản cửu chương 1:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# đây là bản cửu chương 2:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# đây là bản cửu chương 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# đây là bản cửu chương 4:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
# đây là bản cửu chương 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# đây là bản cửu chương 6:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
# ...
