# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/day%201%20variable%20and%20data%20type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
failed_subjects="10"
print('Dear Mrs Badger')
print("Your son Eric is failing " + failed_subjects + " subjects.")
print('Eric will need to redo ' + failed_subjects + '  courses.')
print('Eric is doing well in geography.')

print ("Hello Mr Huy 's world")
# Out:
# Dear Mrs Badger
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_706/3611538311.py in <cell line: 0>()
#       1 failed_subjects="10"
#       2 print('Dear Mrs Badger')
# ----> 3 print("Your son Eric is failing " & failed_subjects & " subjects.")
#       4 print('Eric will need to redo ' + failed_subjects + '  courses.')
#       5 print('Eric is doing well in geography.')
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
