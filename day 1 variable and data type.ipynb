# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/day%201%20variable%20and%20data%20type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
failed_subjects=10
print('Dear Mrs Badger')
print("Your son Eric is failing " + str(failed_subjects) + " subjects.")
print('Eric will need to redo ' + str(failed_subjects) + '  courses.')
print('Eric is doing well in geography.')

print ("Hello Mr Huy 's world. This is the section about datatype")
c1=int("3")
print([c1])
#-----
print ("variable & datatype exercise")
nameItem = "RAMCORSAIR"
Price = 8500
Inventory = 10000
print (nameItem, Price,  Inventory)

Name ="Bui Xuan Huy"
Age = 43
print ("xin chào, tôi là "+Name + str(Age)+ " tuổi")
# Out:
# Dear Mrs Badger
# Your son Eric is failing 10 subjects.
# Eric will need to redo 10  courses.
# Eric is doing well in geography.
# Hello Mr Huy 's world. This is the section about datatype
# [3]
# variable & datatype exercise
# RAMCORSAIR 8500 10000
# xin chào, tôi là Bui Xuan Huy43 tuổi
