# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Day_2_List_Tuples_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print("list lesson")
#Friends = ['Phương','Tuấn','Phụng','Hùng']
#print(Friends) # lấy hết cả danh sách
#print(Friends[0], Friends[2])
#print(len(Friends))
#print(Friends[1:2]) #lấy từ phần tử thứ nhất, đến trước phần tử thứ hai
#print(Friends[1:3])
#print(Friends[:]) # lấy hết cả danh sách
#print(Friends[:2]) #lấy từ phần tử thứ 0, đến trước phần tử thứ 2
#print(Friends[-1]) #lấy phần tử thứ 4 tính từ cuối danh sách
#---
#Nums=[99,100,10,7,2,1000]
#print(Friends )
#Friends.sort()
#print(Friends)
#Friends.sort(reverse=True)
#print(Friends)

#Nums.append(11)
#Nums.insert(0,99)
#Nums[4]=88
#Nums.sort(reverse=True)
#Nums.extend(Friends)
#a=Nums.pop(1)
#print(a)
#Nums.remove(Nums[1])
#print(a)
#---
#print("Tuple lesson")
#Friends_tuple=('Phương','Tuấn','Phụng','Hùng')

#print(Friends[1:3])
#rint(Friends_tuple[1:3])
#print("Dictionary lesson")
#----
print("Dictionary lesson")
Student ={
    "Student_ID" : 9911069,
    "Student_Name" : "Bùi Xuân Huy",
    "Year_Born" : 1981,
          }
print(Student.get("Student_ID"))
print(Student["Student_ID"])
print(Student.keys())
print(Student.values())
for key, value in Student.items():
 print(key, value)
Student['Location']='Hải Phòng'
Student.update({"Year_Born":1981,'Location': 'HP'})
#print(Student)
Student1 = {
    "Student1_ID" : 9911068,
    "Student1_Name" : "Mai Ngọc Khánh LInh",
    "Year_Born" : 1989,
          }
Student2= {
    "Student2_ID" : 9911070,
    "Student2_Name" : "Ngọc Trinh",
    "Year_Born" : 1988,
          }
Student3={
    "Student3_ID" : 9911071,
    "Student_Name" : "Võ Huỳnh Thanh Vân",
    "Year_Born" : 1990,
          }
#Student.update(Student1)
#Student.update(Student2)
#print(Student)
#for groups in ( Student1, Student2, Student3):
 # print(groups)
  #Student.update(groups)
#print(Student)
Student={**Student1, **Student2, **Student3}
print(Student)
if "location" not in Student :
  print("YES")
# Out:
# Dictionary lesson
# 9911069
# 9911069
# dict_keys(['Student_ID', 'Student_Name', 'Year_Born'])
# dict_values([9911069, 'Bùi Xuân Huy', 1981])
# Student_ID 9911069
# Student_Name Bùi Xuân Huy
# Year_Born 1981
# {'Student1_ID': 9911068, 'Student1_Name': 'Mai Ngọc Khánh LInh', 'Year_Born': 1990, 'Student2_ID': 9911070, 'Student2_Name': 'Ngọc Trinh', 'Student3_ID': 9911071, 'Student_Name': 'Võ Huỳnh Thanh Vân'}
# YES
