# %% [markdown]
# <a href="https://colab.research.google.com/github/huybx/AI-learning-week1/blob/main/Day_5_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def ghi_thong_tin():
  Name = input("Họ tên học viên:")
  Age = int(input("Tuổi:"))
  City = input("Thành phố:")
  my_file= open("student.csv","w", encoding="utf-8")
  my_file.write({Name},{Age},{City})
  close(my_file)

def doc_thong_tin():
  with open ("student.csv","r", encoding="utf-8") as file:
    student=file.readline()

  close(file)
# Out:
#   File "/tmp/ipykernel_5404/453125353.py", line 12
#     file.close()
#     ^
# IndentationError: expected an indented block after 'with' statement on line 10
